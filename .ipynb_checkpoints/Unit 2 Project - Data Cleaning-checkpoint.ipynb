# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########
import pandas as pd

#load house_data.csv into a dataframe using pd.read_csv()
house_df = pd.read_csv('house_data.csv')


#load house_sales.csv into a dataframe using pd.read_csv()

sales_df = pd.read_csv('house_sales.csv')


######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully

house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
#    Year Built  Year Renovated  Zipcode      Lat     Long  SQFT living 15  \
# 0      1955.0             NaN  98178.0  47.5112 -122.257            1340
# 1      1951.0          1991.0  98125.0  47.7210 -122.319            1690
# 2      1933.0             NaN  98028.0  47.7379 -122.233            2720
# 3      1965.0             NaN  98136.0  47.5208 -122.393            1360
# 4      1987.0             NaN  98074.0  47.6168 -122.045            1800
#
#    SQFT lot 15
# 0         5650
# 1         7639
# 2         8062
# 3         5000
# 4         7503

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully

sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description:
# >
# > Data type:
#
# **bedrooms**:
# > Description:
# >
# > Data type:
#
# **bathrooms**:
# > Description:
# >
# > Data type:
#
# **sqft_living**:
# > Description:
# >
# > Data type:
#
# **sqft_lot**:
# > Description:
# >
# > Data type:
#
# **floors**:
# > Description:
# >
# > Data type:
#
# **waterfront**:
# > Description:
# >
# > Data type:
#
# **view**:
# > Description:
# >
# > Data type:
#
# **condition**:
# > Description:
# >
# > Data type:
#
# **grade**:
# > Description:
# >
# > Data type:
#
# **sqft_above**:
# > Description:
# >
# > Data type:
#
# **sqft_basement**:
# > Description:
# >
# > Data type:
#
# **yr_built**:
# > Description:
# >
# > Data type:
#
# **yr_renovated**:
# > Description:
# >
# > Data type:
#
# **zipcode**:
# > Description:
# >
# > Data type:
#
# **lat**:
# > Description:
# >
# > Data type:
#
# **long**:
# > Description:
# >
# > Data type:
#
# **sqft_living15**:
# > Description:
# >
# > Data type:
#
# **sqft_lot15**:
# > Description:
# >
# > Data type:

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description:
# >
# > Data type:
#
# **date**:
# > Description:
# >
# > Data type:
#
# **price**:
# > Description:
# >
# > Data type:

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data
house_copy = house_df.copy()

# create a copy of sales_data

sales_copy = sales_df.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully

house_copy.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
#    Year Built  Year Renovated  Zipcode      Lat     Long  SQFT living 15  \
# 0      1955.0             NaN  98178.0  47.5112 -122.257            1340
# 1      1951.0          1991.0  98125.0  47.7210 -122.319            1690
# 2      1933.0             NaN  98028.0  47.7379 -122.233            2720
# 3      1965.0             NaN  98136.0  47.5208 -122.393            1360
# 4      1987.0             NaN  98074.0  47.6168 -122.045            1800
#
#    SQFT lot 15
# 0         5650
# 1         7639
# 2         8062
# 3         5000
# 4         7503

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully

sales_copy.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
#  16  Lat              21612 non-null  float64
#  17  Long             21612 non-null  float64
#  18  SQFT living 15   21613 non-null  int64
#  19  SQFT lot 15      21613 non-null  int64
# dtypes: float64(10), int64(7), object(3)
# memory usage: 3.3+ MB

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?
# Yes

# %% [markdown]
# A: #### TO DO #####
#
# In the house data we need to change zipcode to an object and in the sales data we need to change price to float as well as date to datetime.

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
sales_df.isna().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: ##### TO DO #####
#
# Yes.
#
# In the house data the following have missing values:
#
# - Bathrooms
# - SQFT lot
# - View
# - House Condition
# - Grade
# - SQFT above
# - Year Built
# - Year Renovated
# - Zipcode
# - Lat
# - Long
#
# In the sales data the following have missing vlaues:
#
# - price

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

import seaborn as sns
from scipy.stats import zscore

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
sns.boxplot(data=house_df['Bedrooms'])
# Out:
# <AxesSubplot:>

# %%
house_df['Bedrooms'].describe()
# Out:
# count    21613.000000
# mean         3.372091
# std          0.947533
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: Bedrooms, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT living'])
# Out:
# <AxesSubplot:>

# %%
house_df['SQFT living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: SQFT living, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT lot']);

# %%
house_df['SQFT lot'].describe()
# Out:
# count    2.161100e+04
# mean     1.510388e+04
# std      4.141929e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068750e+04
# max      1.651359e+06
# Name: SQFT lot, dtype: float64

# %%
sns.boxplot(data=house_df['Floors'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=house_df['Grade'])
# Out:
# <AxesSubplot:>

# %%
house_df['Grade'].describe()
# Out:
# count    21611.000000
# mean         7.656795
# std          1.175475
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: Grade, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT above'])
# Out:
# <AxesSubplot:>

# %%
house_df['SQFT above'].describe()
# Out:
# count    21612.000000
# mean      1788.861281
# std        831.369379
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max      12542.000000
# Name: SQFT above, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT basement'])
# Out:
# <AxesSubplot:>

# %%
house_df['SQFT basement'].describe()
# Out:
# count    21613.000000
# mean       291.509045
# std        442.575043
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        560.000000
# max       4820.000000
# Name: SQFT basement, dtype: float64

# %%
sns.boxplot(data=house_df['Year Built'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=house_df['Year Renovated'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=house_df['SQFT living 15'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A: ##### TO DO #####
#
# - Bathrooms
# - Sqft living
# - Sqft lot
# - Grade
# - SQFT above
# - Sqft basement
# - Year Built
# - Year Renovated
# - SQFT Living 15
# - SQFT lot 15

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# ####### TO DO #######
#
# - Drop unnamed 0 column from house data
# - Drop unnamed 0 column from sales data
# - Clean the missing values
# - Look at the outliers and clean that
# - Change zipcode to a string
# - Change date to datetime
# -

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ### 

#Drop unnamed 0 column from house data

### CLEAN ### 

house_df.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###
house_df.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors Waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         View  House Condition  Grade  SQFT above  SQFT basement  Year Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
#    Year Renovated  Zipcode      Lat     Long  SQFT living 15  SQFT lot 15
# 0             NaN  98178.0  47.5112 -122.257            1340         5650
# 1          1991.0  98125.0  47.7210 -122.319            1690         7639
# 2             NaN  98028.0  47.7379 -122.233            2720         8062
# 3             NaN  98136.0  47.5208 -122.393            1360         5000
# 4             NaN  98074.0  47.6168 -122.045            1800         7503

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###
# Make columns in house_df lowercase

### CLEAN ### 
house_df.columns = house_df.columns.str.lower()

### TEST ###
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
#    year renovated  zipcode      lat     long  sqft living 15  sqft lot 15
# 0             NaN  98178.0  47.5112 -122.257            1340         5650
# 1          1991.0  98125.0  47.7210 -122.319            1690         7639
# 2             NaN  98028.0  47.7379 -122.233            2720         8062
# 3             NaN  98136.0  47.5208 -122.393            1360         5000
# 4             NaN  98074.0  47.6168 -122.045            1800         7503

# %%
### DEFINE ###
    # Change to snake case & spaces from column names.


### CLEAN ### 
import regex as re

column_list = house_df.columns.to_list()
new_columns = []

for column in column_list:
    column = column.replace(" ", "_")
    column = column.replace("?", "")
        
    new_columns.append(column)

house_df.columns = new_columns

### TEST ###
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
#    year_renovated  zipcode      lat     long  sqft_living_15  sqft_lot_15
# 0             NaN  98178.0  47.5112 -122.257            1340         5650
# 1          1991.0  98125.0  47.7210 -122.319            1690         7639
# 2             NaN  98028.0  47.7379 -122.233            2720         8062
# 3             NaN  98136.0  47.5208 -122.393            1360         5000
# 4             NaN  98074.0  47.6168 -122.045            1800         7503

# %%
### DEFINE ###

# Change id to a string

### CLEAN ### 

house_df.id = house_df.id.astype(str)

### TEST ###

print(house_df['id']) # successful output should show the id dtype as an object
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: object

# %%
### DEFINE ###

# The id column changed to a string/object.

### CLEAN ### 

sales_df.id = house_df.id.astype(str)


### TEST ###

print(sales_df.id)
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: object
# /var/folders/9q/skxlqygx4xjdfvwtnw5qb98w0000gn/T/ipykernel_14869/2998505554.py:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   sales_df.id = house_df.id.astype(str)

# %%
### DEFINE ###

# Change zipcode column in house to string

### CLEAN ### 

house_df['zipcode'] = house_df['zipcode'].astype(str)

house_df['zipcode'] = house_df['zipcode'].map(lambda x: x.rstrip('.0'))

### TEST ###

print(house_df.zipcode)
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21608    98103
# 21609    98146
# 21610    98144
# 21611    98027
# 21612    98144
# Name: zipcode, Length: 21613, dtype: object

# %%
### DEFINE ###

# drop year renovated column because of the number of 0's and missing values

### CLEAN ### 

house_df.drop(columns=['year_renovated'], inplace=True)

### TEST ###

house_df.info() # successful output will show year_renovated missing from the df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  zipcode          21613 non-null  object
#  14  lat              21612 non-null  float64
#  15  long             21612 non-null  float64
#  16  sqft_living_15   21613 non-null  int64
#  17  sqft_lot_15      21613 non-null  int64
# dtypes: float64(8), int64(5), object(5)
# memory usage: 3.0+ MB

# %%
### DEFINE ###

# There are  missing values in the bathroom column.

### CLEAN ### 

house_df.bathrooms = house_df.bathrooms.fillna(house_df.bathrooms.mean())

### TEST ###

house_df.bathrooms.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

# There are missing values in the condition column 

### CLEAN ### 


condition_mode = house_df['house_condition'].mode()


house_df['house_condition'].fillna(value=condition_mode[0], inplace=True) 

### TEST ###


house_df.house_condition.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

# remove row in the dataframe with null values

### CLEAN ### 

house_df.dropna(axis=0, how='any', inplace=True)

### TEST ###

house_df.isnull().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         0
# view               0
# house_condition    0
# grade              0
# sqft_above         0
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###

# delete rows in sales_df where there are missing values

### CLEAN ### 

sales_df.dropna(axis=0, how='any', inplace=True)

### TEST ###

sales_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         0
# dtype: int64

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
from scipy.stats import zscore

# %%
house_df['bedrooms_zscore'] = zscore(house_df['bedrooms'])

# %%
house_df.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 16     1875500060        30       2.00         1890   14040.0     2.0
# 556    5486800070         7       3.50         4640   15235.0     2.0
# 875    6306400140         0       0.00         3064    4764.0     3.5
# 1135   4024100951         7       3.00         2940    8624.0     1.0
# 1241   7227802030         7       3.00         2800    9569.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 18975  1778360150         7       5.50         6630   13782.0     2.0
# 19254  8812401450        10       3.00         2920    3745.0     2.0
# 19302  3756900027         8       3.00         3840   15990.0     1.0
# 19327  2771604190         7       4.25         3670    4000.0     2.0
# 19452  3980300371         0       0.00          290   20875.0     1.0
#
#       waterfront       view     house_condition  grade  sqft_above  \
# 16            No  Very Poor        OK Condition    7.0      1890.0
# 556           No       Poor        OK Condition   11.0      2860.0
# 875           No    Neutral        OK Condition    7.0      3064.0
# 1135          No  Very Poor        OK Condition    8.0      1690.0
# 1241          No    Neutral        OK Condition    7.0      1400.0
# ...          ...        ...                 ...    ...         ...
# 18975         No  Very Poor        OK Condition   10.0      4930.0
# 19254         No  Very Poor      Good Condition    7.0      1860.0
# 19302         No  Very Poor        OK Condition    7.0      2530.0
# 19327         No       Poor        OK Condition    8.0      2800.0
# 19452         No  Very Poor  Very Bad Condition    1.0       290.0
#
#        sqft_basement  year_built zipcode      lat     long  sqft_living_15  \
# 16                 0      1994.0   98019  47.7277 -121.962            1890
# 556             1780      1965.0    9804  47.5666 -122.231            3230
# 875                0      1990.0   98102  47.6362 -122.322            2360
# 1135            1250      1977.0   98155  47.7555 -122.307            1850
# 1241            1400      1963.0   98056  47.5102 -122.183            2150
# ...              ...         ...     ...      ...      ...             ...
# 18975           1700      2004.0   98006  47.5399 -122.118            4470
# 19254           1060      1913.0   98105  47.6635 -122.320            1810
# 19302           1310      1961.0   98034  47.7111 -122.211            1380
# 19327            870      1964.0   98199  47.6375 -122.388            2010
# 19452              0      1963.0   98024  47.5308 -121.888            1620
#
#        sqft_lot_15  bedrooms_zscore
# 16           14018        28.105651
# 556          20697         3.829103
# 875           4000        -3.559411
# 1135          8031         3.829103
# 1241          7333         3.829103
# ...            ...              ...
# 18975         8639         3.829103
# 19254         3745         6.995609
# 19302         8172         4.884605
# 19327         4000         3.829103
# 19452        22850        -3.559411
#
# [76 rows x 19 columns]

# %%
### DEFINE ###

# remove rows where the bedrooms_zscore column is outside of the 3 threshold

### CODE ### 

house_df = house_df.query('bedrooms_zscore < 3 and bedrooms_zscore > -3').copy()

### TEST ###

house_df.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore]
# Index: []

# %%
house_df['bathrooms_zscores'] = zscore(house_df['bathrooms'])

# %%
house_df.query('bathrooms_zscores > 3 or bathrooms_zscores < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420  101930.0     1.0
# 44     1432701230         3      10.00         1280    9656.0     1.0
# 270    4054500390         4       4.75         5310   57346.0     2.0
# 300    3225069065         4       5.00         4550   18641.0     1.0
# 450    4055700030         3       4.50         3970   24920.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21344  8835770170         5       6.00         6880  279968.0     2.0
# 21494  2413910120         3       4.50         3850   62726.0     2.0
# 21506  2524069097         5       6.50         7270  130017.0     2.0
# 21551  1561750040         5       4.50         4350   13405.0     2.0
# 21576  9253900271         5       4.50         4850   10584.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 5             No  Very Poor    OK Condition   11.0      3890.0           1530
# 44            No  Very Poor  Good Condition    6.0       920.0            360
# 270           No  Very Poor  Good Condition   11.0      5310.0              0
# 300          Yes      Great    OK Condition   10.0      2600.0           1950
# 450           No    Neutral    OK Condition   10.0      3260.0            710
# ...          ...        ...             ...    ...         ...            ...
# 21344         No       Good    OK Condition   12.0      4070.0           2810
# 21494         No  Very Poor    OK Condition   10.0      3120.0            730
# 21506         No  Very Poor    OK Condition   12.0      6420.0            850
# 21551         No  Very Poor    OK Condition   11.0      4350.0              0
# 21576        Yes      Great    OK Condition   10.0      3540.0           1310
#
#        year_built zipcode      lat     long  sqft_living_15  sqft_lot_15  \
# 5          2001.0   98053  47.6561 -122.005            4760       101930
# 44         1959.0   98058  47.4485 -122.175            1340         8808
# 270        1989.0   98077  47.7285 -122.042            4180        47443
# 300        2002.0   98074  47.6053 -122.077            4550        19508
# 450        1977.0   98034  47.7183 -122.258            2610        13838
# ...           ...     ...      ...      ...             ...          ...
# 21344      2007.0   98045  47.4624 -121.779            4690       256803
# 21494      2013.0   98053  47.6735 -122.058            2630        46609
# 21506      2010.0   98027  47.5371 -121.982            1800        44890
# 21551      2014.0   98074  47.6018 -122.060            3990         7208
# 21576      2007.0   98008  47.5943 -122.110            3470        18270
#
#        bedrooms_zscore  bathrooms_zscores
# 5             0.662597           3.126272
# 44           -0.392905          10.324193
# 270           0.662597           3.453450
# 300           0.662597           3.780628
# 450          -0.392905           3.126272
# ...                ...                ...
# 21344         1.718099           5.089341
# 21494        -0.392905           3.126272
# 21506         1.718099           5.743698
# 21551         1.718099           3.126272
# 21576         1.718099           3.126272
#
# [172 rows x 20 columns]

# %%
### DEFINE ###

# remove rows in bathroom column outside of zscore threshold

### CLEAN ### 

house_df = house_df.query('bathrooms_zscores < 3 and bathrooms_zscores > -3').copy()


### TEST ###


house_df.query('bathrooms_zscores > 3 or bathrooms_zscores < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores]
# Index: []

# %%
house_df['sqft_living_zscore'] = zscore(house_df['sqft_living'])

# %%
house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 70     1525059190         5       3.25         4770   50094.0     1.0
# 153    7855801670         4       3.25         5180   19850.0     2.0
# 269    7960900060         4       3.25         5050   20100.0     1.5
# 384     713500030         5       3.50         4800   14984.0     2.0
# 419    8678500060         5       4.25         6070  171626.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21467  2311400056         5       3.50         5230    8960.0     2.0
# 21520  7237550100         4       4.00         4920   50621.0     2.0
# 21521  7430500110         5       3.50         5150   12230.0     2.0
# 21530  8964800330         4       3.75         5090   14823.0     1.0
# 21590  7430200100         4       3.50         4910    9444.0     1.5
#
#       waterfront       view house_condition  grade  ...  sqft_basement  \
# 70            No  Very Poor  Good Condition   11.0  ...           1700
# 153           No       Good    OK Condition   12.0  ...           1640
# 269           No    Neutral    OK Condition   11.0  ...            300
# 384           No    Neutral    OK Condition   11.0  ...           1320
# 419           No  Very Poor    OK Condition   12.0  ...              0
# ...          ...        ...             ...    ...  ...            ...
# 21467         No  Very Poor    OK Condition   11.0  ...            780
# 21520         No  Very Poor    OK Condition   10.0  ...            640
# 21521         No    Neutral    OK Condition   10.0  ...           1450
# 21530         No  Very Poor    OK Condition   11.0  ...            910
# 21590         No  Very Poor    OK Condition   11.0  ...           1800
#
#        year_built  zipcode      lat     long  sqft_living_15  sqft_lot_15  \
# 70         1973.0    98005  47.6525 -122.160            3530        38917
# 153        2006.0    98006  47.5620 -122.162            3160         9750
# 269        1982.0    98004  47.6312 -122.223            3890        20060
# 384        1998.0    98006  47.5543 -122.148            4050        19009
# 419        1999.0    98024  47.5954 -121.950            4680       211267
# ...           ...      ...      ...      ...             ...          ...
# 21467      2014.0    98004  47.5964 -122.201            2310         9603
# 21520      2012.0    98053  47.6575 -122.006            4920        74052
# 21521      2007.0    98008  47.6249 -122.090            2940        13462
# 21530      2013.0    98004  47.6200 -122.207            3030        12752
# 21590      2007.0    98074  47.6502 -122.066            4560        11063
#
#        bedrooms_zscore  bathrooms_zscores  sqft_living_zscore
# 70            1.718099           1.490380            3.158048
# 153           0.662597           1.490380            3.634215
# 269           0.662597           1.490380            3.483235
# 384           1.718099           1.817558            3.192889
# 419           1.718099           2.799093            4.667847
# ...                ...                ...                 ...
# 21467         1.718099           1.817558            3.692284
# 21520         0.662597           2.471915            3.332255
# 21521         1.718099           1.817558            3.599374
# 21530         0.662597           2.144737            3.529691
# 21590         0.662597           1.817558            3.320641
#
# [212 rows x 21 columns]

# %%
house_df['sqft_lot_zscore'] = zscore(house_df['sqft_lot'])

# %%
house_df.query('sqft_lot_zscore > 3 or sqft_lot_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 145    1526069017         4       2.50         3670  315374.0     2.0
# 199    1222069094         3       1.75         1350  155073.0     1.0
# 238     326069104         3       3.50         3830  221284.0     2.0
# 380    1726059053         2       1.50         1380  209959.0     1.0
# 411    2422029094         2       1.00          833  143947.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21090  1624079024         3       2.50         3150  151588.0     2.0
# 21325  2826079027         3       2.50         3090  384634.0     2.0
# 21351  3421069049         2       1.75         1130  276170.0     1.0
# 21431  2725079018         4       3.25         3540  159430.0     2.0
# 21548  8835770330         2       1.50         2370  184231.0     2.0
#
#       waterfront       view     house_condition  grade  ...  year_built  \
# 145           No  Very Poor      Good Condition    9.0  ...      1994.0
# 199           No  Very Poor      Good Condition    7.0  ...      1969.0
# 238           No  Very Poor        OK Condition   10.0  ...      1993.0
# 380           No  Very Poor  Very Bad Condition    6.0  ...      1954.0
# 411           No  Very Poor        OK Condition    5.0  ...      2006.0
# ...          ...        ...                 ...    ...  ...         ...
# 21090         No  Very Poor        OK Condition    9.0  ...      2007.0
# 21325         No  Very Poor        OK Condition    8.0  ...      2007.0
# 21351         No  Very Poor        OK Condition    8.0  ...      2006.0
# 21431         No  Very Poor        OK Condition    9.0  ...      2007.0
# 21548         No  Very Poor        OK Condition   11.0  ...      2005.0
#
#        zipcode      lat     long  sqft_living_15  sqft_lot_15  \
# 145      98077  47.7421 -122.026            2840        87991
# 199      98038  47.4058 -121.994            1560        50965
# 238      98077  47.7641 -122.023            2920       148539
# 380      98011  47.7461 -122.195            3130        19868
# 411       9807  47.3889 -122.482            1380       143947
# ...        ...      ...      ...             ...          ...
# 21090    98024  47.5720 -121.926            2410       208652
# 21325    98019  47.7072 -121.927            2200       292645
# 21351    98022  47.2673 -122.027            2092       217800
# 21431    98014  47.6285 -121.899            1940       392040
# 21548    98045  47.4543 -121.778            3860       151081
#
#        bedrooms_zscore  bathrooms_zscores  sqft_living_zscore  sqft_lot_zscore
# 145           0.662597           0.508845            1.880525         7.358386
# 199          -0.392905          -0.472689           -0.813885         3.432603
# 238          -0.392905           1.817558            2.066347         5.054115
# 380          -1.448407          -0.799868           -0.779044         4.776765
# 411          -1.448407          -1.454224           -1.414321         3.160126
# ...                ...                ...                 ...              ...
# 21090        -0.392905           0.508845            1.276606         3.347255
# 21325        -0.392905           0.508845            1.206923         9.054569
# 21351        -1.448407          -0.472689           -1.069390         6.398277
# 21431         0.662597           1.490380            1.729545         3.539306
# 21548        -1.448407          -0.799868            0.370726         4.146685
#
# [336 rows x 22 columns]

# %%
### DEFINE ###

# remove rows outside of z-score threshold

### CLEAN ### 

house_df = house_df.query('sqft_living_zscore < 3 and sqft_living_zscore > -3').copy()

### TEST ###

house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_living_zscore, sqft_lot_zscore]
# Index: []
#
# [0 rows x 22 columns]

# %%
### DEFINE ###

# remove outliers outside of  threshold

### CLEAN ### 

house_df = house_df.query('sqft_lot_zscore < 3 and sqft_lot_zscore > -3').copy()

### TEST ###

house_df.query('sqft_lot_zscore > 3 or sqft_lot_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_living_zscore, sqft_lot_zscore]
# Index: []
#
# [0 rows x 22 columns]

# %%
house_df['sqft_above_zscore'] = zscore(house_df['sqft_above'])

house_df.query('sqft_above_zscore > 3 or sqft_above_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 431    2944010240         4       3.00         4040   19700.0     2.0
# 509    3885805665         4       3.75         4030   10800.0     2.0
# 512    7322910030         5       3.50         4410   57063.0     2.0
# 563    2725069050         4       2.50         4120   22370.0     2.0
# 679    7852070060         4       3.50         4370   18361.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21532   324069112         4       4.00         4420   16526.0     2.0
# 21561  6664500090         5       4.00         4500    8130.0     2.0
# 21593  8672200110         5       3.75         4170    8142.0     2.0
# 21599  7202300110         4       3.00         3990    7838.0     2.0
# 21600   249000205         5       3.75         4470    8088.0     2.0
#
#       waterfront       view house_condition  grade  ...  zipcode      lat  \
# 431           No  Very Poor    OK Condition   11.0  ...    98052  47.7205
# 509           No  Very Poor    OK Condition   10.0  ...    98033  47.6821
# 512           No  Very Poor  Good Condition    9.0  ...    98053  47.6554
# 563           No  Very Poor    OK Condition   10.0  ...    98074  47.6239
# 679           No  Very Poor    OK Condition   11.0  ...    98065  47.5440
# ...          ...        ...             ...    ...  ...      ...      ...
# 21532         No  Very Poor    OK Condition   11.0  ...    98075  47.5914
# 21561         No  Very Poor    OK Condition   10.0  ...    98059  47.4832
# 21593         No    Neutral    OK Condition   10.0  ...    98056  47.5354
# 21599         No  Very Poor    OK Condition    9.0  ...    98053  47.6857
# 21600         No  Very Poor    OK Condition   11.0  ...    98004  47.6321
#
#           long sqft_living_15  sqft_lot_15  bedrooms_zscore  \
# 431   -122.127           3930        21887         0.662597
# 509   -122.196           2160         7200         0.662597
# 512   -122.018           2900        50529         1.718099
# 563   -122.023           3180         7257         0.662597
# 679   -121.872           4190        13641         0.662597
# ...        ...            ...          ...              ...
# 21532 -122.027           3510        50447         0.662597
# 21561 -122.145           2840         8402         1.718099
# 21593 -122.181           3030         7980         1.718099
# 21599 -122.046           3370         6814         0.662597
# 21600 -122.200           2780         8964         1.718099
#
#        bathrooms_zscores  sqft_living_zscore  sqft_lot_zscore  \
# 431             1.163202            2.310237         0.117308
# 509             2.144737            2.298624        -0.100653
# 512             1.817558            2.739949         1.032331
# 563             0.508845            2.403148         0.182697
# 679             1.817558            2.693494         0.084516
# ...                  ...                 ...              ...
# 21532           2.471915            2.751563         0.039577
# 21561           2.471915            2.844474        -0.166042
# 21593           2.144737            2.461217        -0.165748
# 21599           1.163202            2.252168        -0.173193
# 21600           2.144737            2.809633        -0.167071
#
#        sqft_above_zscore
# 431             3.104553
# 509             3.091105
# 512             3.602110
# 563             3.212133
# 679             3.548320
# ...                  ...
# 21532           3.615558
# 21561           3.723138
# 21593           3.279370
# 21599           3.037315
# 21600           3.682796
#
# [199 rows x 23 columns]

# %%
house_df['sqft_basement_zscore'] = zscore(house_df['sqft_basement'])
house_df.query('sqft_basement_zscore > 3 or sqft_basement_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 10     1736800520         3   2.115173         3560    9796.0     1.0
# 41     7766200013         4   2.250000         4220   24186.0     1.0
# 69     1802000060         5   2.250000         3200   20158.0     1.0
# 115    3626039325         3   3.500000         4380    6350.0     2.0
# 185     825059270         5   3.000000         4090   12850.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 19357  3585300194         5   3.250000         4140   32700.0     1.0
# 19381   868000905         3   2.500000         3480    7800.0     1.0
# 19683  1624049293         5   3.750000         2890    5000.0     1.0
# 20104  1777600850         4   2.250000         3550   13900.0     1.0
# 20921  3864000120         4   3.250000         3780   10099.0     1.0
#
#       waterfront       view house_condition  grade  ...      lat     long  \
# 10            No  Very Poor    OK Condition    8.0  ...  47.6007 -122.145
# 41            No  Very Poor    OK Condition    8.0  ...  47.4450 -122.347
# 69            No  Very Poor    OK Condition    8.0  ...  47.6303 -122.215
# 115           No  Very Poor    OK Condition    8.0  ...  47.6981 -122.368
# 185           No    Neutral  Good Condition   10.0  ...  47.6627 -122.188
# ...          ...        ...             ...    ...  ...      ...      ...
# 19357         No      Great    OK Condition   10.0  ...  47.7633 -122.369
# 19381         No  Very Poor  Good Condition    7.0  ...  47.7047 -122.378
# 19683         No  Very Poor    OK Condition    7.0  ...  47.5701 -122.296
# 20104         No  Very Poor    OK Condition    8.0  ...  47.5681 -122.127
# 20921         No       Poor    OK Condition   11.0  ...  47.5508 -122.192
#
#        sqft_living_15 sqft_lot_15  bedrooms_zscore  bathrooms_zscores  \
# 10               2210        8925        -0.392905           0.005217
# 41               2410       30617         0.662597           0.181667
# 69               3390       20158         1.718099           0.181667
# 115              1830        6350        -0.392905           1.817558
# 185              2540       10270         1.718099           1.163202
# ...               ...         ...              ...                ...
# 19357            3220       22077         1.718099           1.490380
# 19381            3010        9918        -0.392905           0.508845
# 19683            1930        5117         1.718099           2.144737
# 20104            2770       12200         0.662597           0.181667
# 20921            3120       10669         0.662597           1.490380
#
#        sqft_living_zscore  sqft_lot_zscore  sqft_above_zscore  \
# 10               1.752773        -0.125242           0.172995
# 41               2.519287         0.227171           1.168111
# 69               1.334675         0.128525          -0.176640
# 115              2.705108        -0.209634           1.410166
# 185              2.368307        -0.050449           0.482288
# ...                   ...              ...                ...
# 19357            2.426376         0.435679           0.616763
# 19381            1.659862        -0.174124           0.025073
# 19683            0.974646        -0.242696          -0.566618
# 20104            1.741159        -0.024734           0.132653
# 20921            2.008278        -0.117821           0.684001
#
#        sqft_basement_zscore
# 10                 3.395278
# 41                 3.204148
# 69                 3.156365
# 115                3.156365
# 185                4.112018
# ...                     ...
# 19357              3.992561
# 19381              3.466952
# 19683              3.108582
# 20104              3.443061
# 20921              3.013017
#
# [208 rows x 24 columns]

# %%
### DEFINE ###

# remove rows where outliers are outside of threshold

### CLEAN ### 

house_df = house_df.query('sqft_basement_zscore < 3 and sqft_basement_zscore > -3').copy()

### TEST ###

house_df.query('sqft_basement_zscore > 3 or sqft_basement_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscores, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
house_df = house_df.iloc[:,:17].copy()

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20611 entries, 0 to 21612
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20611 non-null  object
#  1   bedrooms         20611 non-null  int64
#  2   bathrooms        20611 non-null  float64
#  3   sqft_living      20611 non-null  int64
#  4   sqft_lot         20611 non-null  float64
#  5   floors           20611 non-null  float64
#  6   waterfront       20611 non-null  object
#  7   view             20611 non-null  object
#  8   house_condition  20611 non-null  object
#  9   grade            20611 non-null  float64
#  10  sqft_above       20611 non-null  float64
#  11  sqft_basement    20611 non-null  int64
#  12  year_built       20611 non-null  float64
#  13  zipcode          20611 non-null  object
#  14  lat              20611 non-null  float64
#  15  long             20611 non-null  float64
#  16  sqft_living_15   20611 non-null  int64
# dtypes: float64(8), int64(4), object(5)
# memory usage: 2.8+ MB

# %%
house_df['year_built_zscore'] = zscore(house_df['year_built'])
house_df.query('year_built_zscore > 3 or year_built_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20981  3746700120         3        3.5         3940   11632.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 20981         No  Very Poor    OK Condition   10.0      3940.0              0
#
#        year_built zipcode     lat     long  sqft_living_15  year_built_zscore
# 20981      1000.0   98166  47.438 -122.344            2015         -32.107034

# %%
### DEFINE ###

# Remove where year built is outside of threshold 
### CLEAN ### 

house_df = house_df.query('year_built != 1000').copy()

### TEST ###

house_df.query('year_built_zscore > 3 or year_built_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, year_built_zscore]
# Index: []

# %%
house_df['sqft_living_15_zscore'] = zscore(house_df['sqft_living_15'])
house_df.query('sqft_living_15_zscore > 3 or sqft_living_15_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21     2524049179         3       2.75         3050   44867.0     1.0
# 283    7202360350         4       2.50         3500    7048.0     2.0
# 431    2944010240         4       3.00         4040   19700.0     2.0
# 473    8651610890         4       3.25         4190   10259.0     2.0
# 545    2944000240         4       2.50         3350   29242.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21254  7852120050         4       3.50         3510   10010.0     2.0
# 21375  6061500100         6       3.50         4310    7760.0     2.0
# 21486    98300230         4       4.00         4620  130208.0     2.0
# 21525  2625069038         4       3.50         4300  108865.0     2.0
# 21540   715010530         5       3.50         4410   13000.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 21            No      Great    OK Condition    9.0      2330.0            720
# 283           No  Very Poor    OK Condition    9.0      3500.0              0
# 431           No  Very Poor    OK Condition   11.0      4040.0              0
# 473           No  Very Poor    OK Condition   11.0      3150.0           1040
# 545           No  Very Poor    OK Condition   11.0      3350.0              0
# ...          ...        ...             ...    ...         ...            ...
# 21254         No  Very Poor    OK Condition   10.0      3510.0              0
# 21375         No  Very Poor    OK Condition   10.0      3260.0           1050
# 21486         No  Very Poor    OK Condition   10.0      4620.0              0
# 21525         No  Very Poor    OK Condition   11.0      4300.0              0
# 21540         No       Good    OK Condition   10.0      2920.0           1490
#
#        year_built zipcode      lat     long  sqft_living_15  \
# 21         1968.0    9804  47.5316 -122.233            4110
# 283        2005.0   98053  47.6811 -122.025            3920
# 431        1987.0   98052  47.7205 -122.127            3930
# 473        2000.0   98074  47.6332 -122.066            4300
# 545        1988.0   98052  47.7197 -122.131            3920
# ...           ...     ...      ...      ...             ...
# 21254      2001.0   98065  47.5412 -121.876            4200
# 21375      2013.0   98059  47.5297 -122.155            4620
# 21486      2014.0   98024  47.5885 -121.939            4620
# 21525      2014.0   98074  47.6258 -122.005            4650
# 21540      2014.0   98006  47.5382 -122.111            5790
#
#        year_built_zscore  sqft_living_15_zscore
# 21             -0.081983               3.374163
# 283             1.142115               3.078069
# 431             0.546608               3.093652
# 473             0.976696               3.670257
# 545             0.579692               3.078069
# ...                  ...                    ...
# 21254           1.009780               3.514418
# 21375           1.406785               4.168942
# 21486           1.439869               4.168942
# 21525           1.439869               4.215694
# 21540           1.439869               5.992260
#
# [204 rows x 19 columns]

# %%
house_df['sqft_living_15_zscore'] = zscore(house_df['sqft_living_15'])
house_df.query('sqft_living_15_zscore > 3 or sqft_living_15_zscore < -3')
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21     2524049179         3       2.75         3050   44867.0     1.0
# 283    7202360350         4       2.50         3500    7048.0     2.0
# 431    2944010240         4       3.00         4040   19700.0     2.0
# 473    8651610890         4       3.25         4190   10259.0     2.0
# 545    2944000240         4       2.50         3350   29242.0     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21254  7852120050         4       3.50         3510   10010.0     2.0
# 21375  6061500100         6       3.50         4310    7760.0     2.0
# 21486    98300230         4       4.00         4620  130208.0     2.0
# 21525  2625069038         4       3.50         4300  108865.0     2.0
# 21540   715010530         5       3.50         4410   13000.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 21            No      Great    OK Condition    9.0      2330.0            720
# 283           No  Very Poor    OK Condition    9.0      3500.0              0
# 431           No  Very Poor    OK Condition   11.0      4040.0              0
# 473           No  Very Poor    OK Condition   11.0      3150.0           1040
# 545           No  Very Poor    OK Condition   11.0      3350.0              0
# ...          ...        ...             ...    ...         ...            ...
# 21254         No  Very Poor    OK Condition   10.0      3510.0              0
# 21375         No  Very Poor    OK Condition   10.0      3260.0           1050
# 21486         No  Very Poor    OK Condition   10.0      4620.0              0
# 21525         No  Very Poor    OK Condition   11.0      4300.0              0
# 21540         No       Good    OK Condition   10.0      2920.0           1490
#
#        year_built zipcode      lat     long  sqft_living_15  \
# 21         1968.0    9804  47.5316 -122.233            4110
# 283        2005.0   98053  47.6811 -122.025            3920
# 431        1987.0   98052  47.7205 -122.127            3930
# 473        2000.0   98074  47.6332 -122.066            4300
# 545        1988.0   98052  47.7197 -122.131            3920
# ...           ...     ...      ...      ...             ...
# 21254      2001.0   98065  47.5412 -121.876            4200
# 21375      2013.0   98059  47.5297 -122.155            4620
# 21486      2014.0   98024  47.5885 -121.939            4620
# 21525      2014.0   98074  47.6258 -122.005            4650
# 21540      2014.0   98006  47.5382 -122.111            5790
#
#        year_built_zscore  sqft_living_15_zscore
# 21             -0.081983               3.374163
# 283             1.142115               3.078069
# 431             0.546608               3.093652
# 473             0.976696               3.670257
# 545             0.579692               3.078069
# ...                  ...                    ...
# 21254           1.009780               3.514418
# 21375           1.406785               4.168942
# 21486           1.439869               4.168942
# 21525           1.439869               4.215694
# 21540           1.439869               5.992260
#
# [204 rows x 19 columns]

# %%
sales_df = sales_df.iloc[:, :-1].copy()

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21609 non-null  int64
#  1   Id          21609 non-null  int64
#  2   DATE        21609 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 675.3+ KB

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ####### TO DO ###### - Edit this cell to add your summary and justification per project instructions.
#
#
# - Dropped unnamed 0 column from house data
# - Dropped unnamed 0 column from sales data
# - Made columns lower case
# - Changed id to string/object
# - Changed zipcode to string/object

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
#   zipcode      lat     long  sqft_living_15  year_built_zscore  \
# 0   98178  47.5112 -122.257            1340          -0.512071
# 1   98125  47.7210 -122.319            1690          -0.644406
# 2   98028  47.7379 -122.233            2720          -1.239914
# 3   98136  47.5208 -122.393            1360          -0.181234
# 4   98074  47.6168 -122.045            1800           0.546608
#
#    sqft_living_15_zscore
# 0              -0.942581
# 1              -0.397144
# 2               1.207999
# 3              -0.911413
# 4              -0.225721

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - waterfrontnominal data
# - view - replace with weighted integers - nominal data
# - house_condition - replace with weighted integers - nominal data

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
#
#
# - waterfront: Replace with (yes=1, no=0)
# - view:Replace with 1-5 scale.
# - house_condition: Replace with 1-5 scale.

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.waterfront.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
house_df['waterfront'] = house_df['waterfront'].replace({'Yes':1, "No":0})

# %%
house_df.waterfront.unique()
# Out:
# array([0, 1])

# %%
house_df.view.unique()
# Out:
# array(['Very Poor', 'Good', 'Great', 'Neutral', 'Poor'], dtype=object)

# %%
house_df['view'] = house_df['view'].replace({'Very Poor':1, 'Poor':2, 'Neutral':3, 'Good':4, 'Great':5})

# %%
house_df['view'].unique()
# Out:
# array([1, 4, 5, 3, 2])

# %%
house_df['house_condition'].unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition'], dtype=object)

# %%
house_df['house_condition'].unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition'], dtype=object)

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to add your summary and justification per project instructions.
#
# - waterfront - replaced 'No' with 0 and 'Yes' with 1
# - view - replaced with weighted integers (scale of 1-5 for very poor - great)
# - house_condition - replaced with weighted integers (1-5 for bad condition - great condition)
#
# - waterfront: Yes and No values are replced with 1/0, which shows the boolean functions.
# - View: qualitative data to quantitative data in order to change the categorical words to numerical (1-5).
# - house_condition:qualitative data to quantitative data in order to change the categorical words to numerical (1-5).

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.
#
# Merging the house data and sales data with .merge() method so that the corresponding vlaues match and combine in one row instead of two different data files. This will cleans the data and concise it by removing unmatched values.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
master_df = sales_df.merge(house_df, on='id')

# %%
# Use .head() method to print first few rows of new master dataframe

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
